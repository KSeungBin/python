# %% [markdown]
# ## 1. colab의 하드웨어 성능

# %% [markdown]
# ### OS 환경

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# ###  CPU 사양

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 1999.999
# cache size	: 39424 KB
# physical id	: 0

# %% [markdown]
# ### 메모리 사양

# %%
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:        10588892 kB
# MemAvailable:   12509492 kB

# %% [markdown]
# ### python 버젼

# %%
# !python --version
# Out:
# Python 3.7.11

# %% [markdown]
# ## 1-1. GPU 사용하기

# %% [markdown]
# 수정 -> 노트 설정 -> 하드웨어 가속기 -> GPU 설정
# 자원할당 부분 -> 리소스보기 -> 런타임 유형 변경 -> GPU 설정

# %% [markdown]
# ## 2. 왼쪽 아이콘 메뉴 설명

# %% [markdown]
# 1. 목차
# 2. 파일 탐색기
# 3. 리소스 보기- 할당 여부 확인 하기 (RAM/디스크)
# 4. 파일 공유, 댓글 (전체 파일에 대하여 / 셀에 대하여)

# %% [markdown]
# ## 3. 셀의 종류 (코드/텍스트)

# %% [markdown]
# 코드 셀: 코드 실행을 위한 셀

# %% [markdown]
# 텍스트 셀: 주석을 달거나, 설명 문구등을 달기 위한 텍스트 전용 셀

# %% [markdown]
# ### 3-1. 주석과 텍스트 셀의 차이

# %% [markdown]
# 텍스트 셀, 코드 설명 등 추가, 마크다운 language

# %%
# 코드 넣기
# Out:
# 헬로 코랩

# %%
# 이렇게 주석을 달 수 있습니다.
print('헬로 코랩')
# Out:
# 헬로 코랩

# %%
# 주석입니다.
print('헬로 코랩')

# 주석입니다.
print('헬로 코랩')
# Out:
# 헬로 코랩
# 헬로 코랩

# %% [markdown]
# ### 3-2. 셀의 삽입 방법

# %% [markdown]
# 상단의 "+코드", "+텍스트"를 눌러서 삽입함

# %% [markdown]
# **[셀 추가 관련 단축키]**
#
# 1. 코드 셀 위에 삽입 (Ctrl/Cmd + M A)
# 2. 코드 셀 아래에 삽입 (Ctrl/Cmd + M B)

# %% [markdown]
# 텍스트

# %% [markdown]
# ### 3-3. 셀의 삭제 방법

# %% [markdown]
# 우측의 **휴지통 아이콘을 클릭**하여 삭제함

# %% [markdown]
# **[셀 삭제 관련 단축키]**

# %% [markdown]
# 셀 지우기 (Ctrl/Cmd + M D)
# 셀 지우기 (Ctrl/Cmd + M Z)

# %% [markdown]
# ### 3-4 셀의 타입 변경

# %% [markdown]
# **[셀 타입 변경 단축키]**
# 1. 코드 셀로 변경 (Ctrl/Cmd + M Y)
# 2. 마크다운 셀로 변경 (Ctrl/Cmd + M M)

# %% [markdown]
# print('안녕하세요')

# %% [markdown]
# ## 4. 실행과 출력

# %% [markdown]
# * **셀**: 실행의 단위
# * **실행**: 재생 버튼을 클릭하여, 실행 (해당 셀 실행)
# * **실행 순서**: *인터프리터 방식* 으로 실행하며, 순차적으로 메모리에 기억함

# %% [markdown]
# **[실행 관련 단축키]**
#
# 1. 해당 셀을 실행하고 커서는 해당 셀  (Ctrl + Enter)
# 2. 해당 셀을 실행하고 커서는 다음 셀  (Shift + Enter)
# 3. 해당 셀을 실행하고 커서는 다음에 셀 삽입  (Alt + Enter)

# %%
print('헬로 코랩')
# Out:
# 헬로 코랩

# %% [markdown]
# ## 5. 단축키 확인하기

# %% [markdown]
# Ctrl + M H (키보드 단축키 보기)

# %% [markdown]
# ## 6. 마크다운 문법의 이해

# %% [markdown]
# Markdown(마크다운)이란 Markup(마크업)언어의 일종으로,
# **HTML경험이 없는 사람도 누구나 쉽게** 헤더,글 머리 기호,이미지 삽입, 링크, 글자 모양 등 서식, 편집 가능

# %% [markdown]
# **[실습예제]**
# ## colab 이란?
# Google Colaboratory
#
# 구글에서 **교육과 과학 연구를 목적**으로 개발한 도구로, 2017년에 무료로 공개함
#
# ### 장점
# 1. 무료
# 2. 구글 드라이브와 연동 가능
# 3. GPU/TPU를 사용할 수 있음
# 4. 깃헙(Github)에 있는 노트북 코드를 바로 돌려볼 수 있음
# 5. 손 쉽게 타인과 공유할 수 있음
#
#
# ### 단점
# 1. 90분동안 아무런 인터액션이 없거나 (idle timeout), 12시간의 ***세션 타임아웃***이 존재함
#  - [참고] teddylee777.github.io/colab/google-colab-런타임-연결끊김방지
# 2. GPU는 할당을 못받을 수도 있음 (혹은 빼앗기는 경우도 있음)
# 3. 조금 느림

# %% [markdown]
# # 헤더
#
# 구글에서 교육과 **과학 연구**를 목적으로 개발한 도구로, 2017년에 무료로 공개함.
# 1. 순서1
# 2. 순서1
# 3. 순서1
#
#
# * 순서없다
# * 순서없다
# * 순서없다

# %% [markdown]
# ## 7. 파일 업로드 하기

# %% [markdown]
# ### 방법 1: 직접 업로드하기

# %%
from google.colab import files
# Out:
#      <input type="file" id="files-c4bd4239-0208-478d-9e7d-441c9bf5c876" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4bd4239-0208-478d-9e7d-441c9bf5c876">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_price.csv to house_price (1).csv

# %%
import io
import pandas as pd

# %%
# 업로딩 데이터 dataframe으로 로딩
data = pd.read_csv(io.BytesIO(myfile['house_price.csv']))

# %%
data.head()

# %% [markdown]
# ### 방법 2: 구글 드라이브에서 업로딩하기

# %%
# 드라이브  마운트 하기
from google.colab import drive
# Out:
# Mounted at /content/drive

# %%
# 기본 path 설정하기
import os
os.chdir(r"/content/drive/MyDrive/RAPA_python_lib/data")

# %%
# pandas 데이터 프레임으로 업로딩
import pandas as pd

# %%
data.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %% [markdown]
# ### 방법3. colab 플랫폼에 업로딩하는 방식

# %%
# 판다스 데이터 프레임 객체로 업로딩
import pandas as pd

# %% [markdown]
# ## 8. 그 밖의 기능 - 이미지, Youtube 동영상 로딩하기

# %%
# 이미지 출력

# %%
# 유튜브 출력
from IPython.display import YouTubeVideo
# https://youtu.be/KR8ddnPjCtk

# %%
# 홈페이지 출력
from IPython.display import HTML

HTML('https://www.naver.com/')
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...
