# %% [markdown]
# <a href="https://colab.research.google.com/github/KSeungBin/python/blob/master/03_package_visualization_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualization (시각화)
# > 데이터분석 및 보고에 필요한 시각화 패키지를 알아보고 실제 데이터로 시각화 예제를 다루어봅니다.
# 데이터 시각화는 데이터분석 과정에서 단순히 데이터를 살펴보는데 그치지 않고 다양한 분석 가능성을 보여줍니다.
# 또한 3자에게 설명을 함에 있어서도 데이터시각화는 굉장히 설득력있는 리포팅을 가능하게 해줍니다.

# %% [markdown]
# ## **Matplotlib**
# > - 파이썬의 대표적인 시각화 패키지
# > - 패키지의 이름에서 느껴지듯 MATLAB의 수리데이터 시각화를 파이썬으로 옮겨온 컨셉
# > - 기본적인 형태의 다양한 시각화 함수를 제공
# > - 사용이 약간은 불편

# %% [markdown]
# ### matplotlib 설치 및 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install matplotlib
# matlab 사용자의 시각화 도구 사용가능
# 분석에 사용가능한 여러가지 시각화 함수를 제공합니다. 보통 plt라는 예명으로 사용합니다.

# %matplotlib inline 
# 주피터 노트북에 최적화 된 그래프 설정(코랩에서 사용불가한 magic 명령어)

# %matplotlib notebook 
# 인터렉티브 그래프 가능(코랩 사용불가) - 마우스로 그래프 컨트롤 가능

# %% [markdown]
# #### 코랩 시각화 한글 폰트 사용

# %%
# 코랩
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 재시작

# %% [markdown]
# #### 윈도우 한글 폰트 사용
# > - 윈도우 자체 한글폰트 사용가능
# > - 저작권 걱정없는 무료 한글 폰트 [https://brunch.co.kr/@jade/203](https://brunch.co.kr/@jade/203)
# > - 네이버에서 배포하는 나눔바른고딕체 [https://hangeul.naver.com/font](https://hangeul.naver.com/font)

# %%
# family 파라메터에 사용가능한 폰트이름 전달(가장 간단한 방법)
plt.rc('font', family='NanumBarunGothic')

# %%
# 사용가능한 폰트 목록 확인
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()

# %%
# 혹은 폰트 경로를 직접 전달해줘도 동작합니다.
# 다만 사용가능한 폰트 목록과 확장자명 확인이 필요합니다.
font_location = 'C:/Windows/Fonts/malgun.ttf' # for windows
# font_location = '/Library/Fonts/Arial Unicode.ttf' # for 맥
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %% [markdown]
# ### 기본적인 line plot 그리기
#     line plot은 시간 혹은 순서에 따라 데이터가 어떻게 변화하는지를 보기위해 주로 사용합니다.
#     ex) 주가데이터, 전력수요량, 매출, 수요

# %%
# numpy array로 시각화 데이터 생성
# arange, linspace
x = np.arange(-10, 10)
y = x ** 2

x1 = np.linspace(-10, 10, 50)
y1 = x1 ** 2

# %%
# line plot - plt.plot(x축 데이터, y축 데이터)
# plt.show() plt 함수로 정의 한 그래프 설정을 그래프화 시키는 명령어
plt.plot(x1, y1)

# %% [markdown]
# #### 스타일 지정
#     plot명령어는 보는 사람이 그래프를 조금 더 보기 편하게 하기 위한 다양한 스타일을 지원합니다.
#     plot(데이터, '문자열인수')

# %%
# line plot 스타일 지정
# 스타일 문자열은 색, 마커, 선 종류 순으로 지정하며 만약 이중 일부가 생략되면 디폴트 값이 적용됩니다.
plt.plot(x1, y1, 'c.-')

# %% [markdown]
# #### 자주 사용하는 선스타일 색상
#     자주 사용되는 색깔은 한글자 약자를 사용할 수 있으며 약자는 아래 표에 정리하였습니다.
# | 색상 | 약자 |
# |-|-|
# | blue | `b` |
# | green | `g` |
# | red | `r` |
# | cyan | `c` |
# | magenta | `m` |
# | yellow | `y` |
# | black | `k` |
# | white | `w` |

# %% [markdown]
# #### 마커
#     데이터의 위치를 표기하는 기호를 마커라고 합니다.
#     사용가능한 마커의 종류를 아래 정리 해두었습니다.
# | 마커 문자열 | 의미 | 마커 문자열 | 의미 |
# |-|-|-|-|
# | `.` | point marker  | `1` | tri_down marker |
# | `,` | pixel marker | `2` | tri_up marker |
# | `o` | circle marker | `3` | tri_left marker |
# | `v` | triangle_down marker | `4` | tri_right marker |
# | `^` | triangle_up marker | `s` | square marker |
# | `<` | triangle_left marker | `p` | pentagon marker |
# | `>` | triangle_right marker | `*` | star marker |
# | `h` | hexagon1 marker | `x` | x marker |
# | `H` | hexagon2 marker | `D` | diamond marker |
# | `+` | plus marker | `d` | thin_diamond marker |

# %% [markdown]
# #### 선 스타일
#     선 스타일에는 실선(solid), 대시선(dashed), 점선(dotted), 대시-점선(dash-dit)을 사용가능합니다.
#
# | 선 스타일 문자열 | 의미 |
# |-|-|
# | `-` |  solid line style
# | `--` |  dashed line style
# | `-.` |  dash-dot line style
# | `:` |  dotted line style

# %% [markdown]
# #### 그래프에 옵션 추가하기
# 지금부터는 plt 의 다른 함수를 사용하여 보는 사람의 이해를 도울 수 있는 여러 기능들을 알아보겠습니다.
#
# - `figure` : 그래프가 그려지는 캔버스 설정
# - `title` : 그래프 제목
# - `xlabel`, `ylabel` : 축 설명
# - `legend` : 범례이름
# - `xlim`, `ylim` : 축 범위
# - `xticks`, `yticks` : 축 구간 내 필요한 구간만 추리기

# %%
# 그래프 크기조정 figsize=(가로 세로 사이즈 튜플 전달)
plt.figure(figsize = (10, 5))  # 단위 inch
plt.plot(x1, y1, '-')   # 그래프 설정
plt.show()                # 그래프 그리기 마무리

# %%
# 그래프 타이틀 지정
plt.figure(figsize = (10, 5))  
plt.title('$x^2$')   # '$$' 하면 수학 기호 표현 가능
plt.plot(x1, y1, '-')  
plt.show()

# %%
# 축 타이틀 지정 (축 설명)
plt.figure(figsize = (10, 5))  
plt.title('$x^2$') 
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x1, y1, '-')   
plt.show()

# %%
y2 = x1 ** 3

# 범례지정 : 그래프에 플로팅된 데이터가 무엇을 의미하는지 나타내는 방법
# plot에 label지정 plt.legend()
plt.figure(figsize = (10, 5))  
plt.title('$x^2$') 
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x1, y1, ':', label='$x^2$')   
plt.plot(x1, y2, 'r:', label='$x^3$')
plt.legend(loc=1)  # default는 loc='best'
plt.show()

# %%
# 축 범위 설정 : 위 그래프는 x**2 그래프 형태가 잘 드러나지 않기 때문
# 시각화하면서 그래프의 정확성에 신경써야 함
plt.figure(figsize = (10, 10))  
plt.title('$x^2$') 
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x1, y1, ':', label='$x^2$')   
plt.plot(x1, y2, 'r:', label='$x^3$')
plt.xlim([-5,5])
plt.ylim([-10,10])
plt.legend(loc=1)  
plt.show()

# %%
# 축 구간 지정
plt.figure(figsize = (10, 10))  
plt.title('$x^2$') 
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x1, y1, ':', label='$x^2$')   
plt.plot(x1, y2, 'r:', label='$x^3$')
plt.xlim([-5,5])
plt.ylim([-10,10])
plt.xticks([-5,0,5], rotation=90)   # x축의 데이터가 너무 많아 텍스트가 뭉쳐나올 때 사용
plt.legend(loc=1)  
plt.show()

# %% [markdown]
# #### 연습문제
# > y축에 x의 세제곱 그래프를 그려봅니다.
# > 라인은 노랑색, 선은 실선, 마커는 없어요.
# > 제목은 '$X^3$', plot label=''$x^3$' 범례지정도 해주세요

# %%
# CODE HERE

# %% [markdown]
# ### 여러가지 그래프 한꺼번에 그리기

# %%
plt.figure(figsize=(10, 7))
plt.title('$x^2$ and $x^3$')
x = np.linspace(-10, 10, 300)
plt.plot(x, x*x, label='$x^2$')
plt.plot(x, x*x*x, 'r--', label='$x^3$')
plt.plot(x, np.sin(x), 'g:', label='$sin(x)$')
plt.plot(x, np.cos(x), 'k:', label='$cos(x)$')
plt.ylabel('$x^2$ and $x^3$')
plt.xlabel('x')
plt.xlim(-3, 3)
plt.ylim(-1, 1)  # x축, y축 범위설정 중요 : sin, cos 그래프는 -1~1 사이 값 가지기 때문
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### subplot을 사용하여 여러 그래프를 개별적으로 그리기

# %%
# 2 x 1 figure 매트릭스에 그래프 그리기

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.figure(figsize=(12, 8))

# (4, 5, i)  => 4 * 5 = 20개의 도화지로 나뉘는데 i로 지정해 반복문 돌릴 수 있음
plt.subplot(211) # 도화지 나누기 2행 1열 그래프의 첫번째  (2,1,1)도 OK
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(212) # 도화지 나누기 2행 1열 그래프의 두번째
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout() # 여백줄이기
plt.show()

# %% [markdown]
# #### subplot 연습문제
# > 2 x 2 figure subplot설정
# > 매트릭스에 위에 1.3에서 그린 제곱, 세제곱, sin, cos 그래프 나누어 그려봅시다

# %%
# CODE HERE
plt.figure(figsize=(15, 10))
plt.title('$x^2$ and $x^3$')
x = np.linspace(-10, 10, 300)

plt.subplot(2,2,1)
plt.plot(x, x*x, label='$x^2$')
plt.legend(loc='best')

plt.subplot(2,2,2)
plt.plot(x, x*x*x, 'r--', label='$x^3$')
plt.legend(loc='best')

plt.subplot(2,2,3)
plt.plot(x, np.sin(x), 'g:', label='$sin(x)$')
plt.legend(loc='best')

plt.subplot(2,2,4)
plt.plot(x, np.cos(x), 'k:', label='$cos(x)$')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### bar plot
# > bar plot은 범주형 데이터(구간이 나누어져 있는) 데이터의 갯수, 빈도를 나타내는 데 사용됩니다.
# 지난 시간 학습한 loan 데이터의 신용등급을 bar plot으로 그려보겠습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loan1.csv 파일 불러들이기
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2022-04-22 python_advanced/advance/data/loan1.csv')

# %%
# 세부신용등급 각 항목별 갯수세기
print(df['sub_grade'].value_counts().index)   # x축
print(df['sub_grade'].value_counts().values)  # y축

# 전체 데이터 분포를 보려면 값 기준보다 인덱스 기준으로 정렬하는 것이 좋다
df['sub_grade'].value_counts().sort_index()
# Out:
# Index(['B5', 'B3', 'B1', 'B2', 'C1', 'C2', 'C3', 'A4', 'A5', 'C4', 'A3', 'C5',
#        'B4', 'A2', 'D1', 'D2', 'D3', 'A1', 'D4', 'D5', 'E2', 'E3', 'E4', 'E5',
#        'E1', 'F1', 'G1', 'F3', 'F4', 'F2', 'F5', 'G5', 'G2', 'G4'],
#       dtype='object')
# [1359 1356 1338 1309 1168 1134 1104 1064 1002  978  967  962  948  830
#   717  635  616  598  544  508  184  176  132  111   91   69   29   20
#    18   18   12    1    1    1]
# A1     598
# A2     830
# A3     967
# A4    1064
# A5    1002
# B1    1338
# B2    1309
# B3    1356
# B4     948
# B5    1359
# C1    1168
# C2    1134
# C3    1104
# C4     978
# C5     962
# D1     717
# D2     635
# D3     616
# D4     544
# D5     508
# E1      91
# E2     184
# E3     176
# E4     132
# E5     111
# F1      69
# F2      18
# F3      20
# F4      18
# F5      12
# G1      29
# G2       1
# G4       1
# G5       1
# Name: sub_grade, dtype: int64

# %%
# 세부신용등급 bar plot
plt.figure(figsize=(15,8))
plt.bar(df['sub_grade'].value_counts().sort_index().index, df['sub_grade'].value_counts().sort_index().values)
plt.show()

# %%
# 세부신용등급 barh plot
plt.figure(figsize=(15,8))
plt.barh(df['sub_grade'].value_counts().sort_index(ascending=False).index, df['sub_grade'].value_counts().sort_index(ascending=False).values)
plt.show()

# %% [markdown]
# ### 히스토그램
# > 데이터의 분포를 확인하고자 할 때 많이 사용하는 시각화 방법입니다.
# 전체 데이터 구간 중 특정 구간에 속한 데이터의 빈도수를 계산하여 구간에 매칭시킵니다.
# 데이터 구간별 밀도를 확인할 수 있습니다.

# %%
df.head()
# 얼마빌렸는가 loan_amnt가 핵심 column
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       3500         3500           3500.0   36 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN      14000        14000          14000.0   36 months
# 4 NaN        NaN       5000         5000           5000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0      9.44       320.05     B        B1  ...                            NaN
# 1     10.42       113.63     B        B3  ...                            NaN
# 2     13.59       169.90     C        C2  ...                            NaN
# 3     10.91       457.75     B        B4  ...                            NaN
# 4     13.59       169.90     C        C2  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# ...

# %%
# 대출금액분포 hist plot으로 확인
plt.figure(figsize=(15,6))
plt.hist(df['loan_amnt'], bins=25) # 전체 데이터를 가장 잘 설명하는 최적 구간을 bins로 searching해야 함
plt.show()

# 결론 : 사람들은 대출을 5000 단위로 많이 한다. 40000 이상은 없으니 대출 제한이 있는 듯. 20000 이상 받은 건수도 줄어들지 않고 고른 분포

# %% [markdown]
# ### scatter plot
# > 2개 혹은 2개 이상의 변수간의 관계를 확인하고자 할 때 많이 사용하는 시각화 방법.
# X축과 Y축에 각각의 변수 데이터를 위치시키고 포인트들이 자리한 평면상의 분포를 통해 "상관관계"를 파악할 수 있습니다.

# %%
# 각각의 변수와 우리가 보고자 하는 값과의 관계를 볼 때 가장 많이 사용합니다.
# loan_amnt(대출금액), installment(원리금) : 대출금액이 많을수록 원리금(갚아야할 금액)도 많아진다
# 캔버스에 그려지는 점하나가 샘플 하나
plt.figure(figsize=(15,6))
plt.scatter(df['loan_amnt'], df['installment'])
plt.show()

# scatter plot의 point 하나 = sample 하나

# %% [markdown]
# ## matplotlib 예제 살펴보기
# 데이터를 가장 잘 표현할 수 있는 시각화 방법을 고민해야 한다
#    -> matplotlib 공식 홈페이지에 있는 샘플 예쩨를 보며 감 익히기
#    -> https://matplotlib.org/stable/gallery/index
#
# ### 샘플예제

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30],
         [0, -1],
         slice(100, 200, 3),
         0.1,
         0.3,
         1.5,
         (0.0, 0.1),
         (0.45, 0.1)]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2 * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Support for axes.prop_cycle cycler with markevery')

plt.show()

# %% [markdown]
# ### 동적그래프 샘플예제

# %%
# 3차원 그래프
# %matplotlib notebook   # 매직 명령어 : 코랩에서는 작동하지 않아 주피터 노트북에서만 그릴 수 있음
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook # 3D plot을 인터랙티브하게 움직일 수 있도록 주피터노트북 설정
# %matplotlib inline # plot크기를 주피터 노트북에 알맞게(크기에 벗어나지 않게 그려줌)

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

# Prepare arrays x, y, z
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
# Out:
# <div id='07ba763d-bd08-461b-95fe-918e9e885ed8'></div>
# <div id='d60bc97d-b557-41fc-84fb-31a88d712ba7'></div>

# %% [markdown]
# ### 애니메이션 샘플예제

# %%
# 코랩이 아닌 환경에서는 애니메이션 효과도 지원함
# 중심점을 기준으로 무게추의 움직임을 애니메이션으로 (크레인 or 로봇팔 반경 등을 시각화, 날씨가 추워졌을 때 움직임 반경 ...)
from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import matplotlib.animation as animation
from collections import deque
# %matplotlib notebook

G = 9.8  # acceleration due to gravity, in m/s^2
L1 = 1.0  # length of pendulum 1 in m
L2 = 1.0  # length of pendulum 2 in m
L = L1 + L2  # maximal length of the combined pendulum
M1 = 1.0  # mass of pendulum 1 in kg
M2 = 1.0  # mass of pendulum 2 in kg
t_stop = 5  # how many seconds to simulate
history_len = 500  # how many trajectory points to display


def derivs(state, t):

    dydx = np.zeros_like(state)
    dydx[0] = state[1]

    delta = state[2] - state[0]
    den1 = (M1+M2) * L1 - M2 * L1 * cos(delta) * cos(delta)
    dydx[1] = ((M2 * L1 * state[1] * state[1] * sin(delta) * cos(delta)
                + M2 * G * sin(state[2]) * cos(delta)
                + M2 * L2 * state[3] * state[3] * sin(delta)
                - (M1+M2) * G * sin(state[0]))
               / den1)

    dydx[2] = state[3]

    den2 = (L2/L1) * den1
    dydx[3] = ((- M2 * L2 * state[3] * state[3] * sin(delta) * cos(delta)
                + (M1+M2) * G * sin(state[0]) * cos(delta)
                - (M1+M2) * L1 * state[1] * state[1] * sin(delta)
                - (M1+M2) * G * sin(state[2]))
               / den2)

    return dydx

# create a time array from 0..t_stop sampled at 0.02 second steps
dt = 0.02
t = np.arange(0, t_stop, dt)

# th1 and th2 are the initial angles (degrees)
# w10 and w20 are the initial angular velocities (degrees per second)
th1 = 120.0
w1 = 0.0
th2 = -10.0
w2 = 0.0

# initial state
state = np.radians([th1, w1, th2, w2])

# integrate your ODE using scipy.integrate.
y = integrate.odeint(derivs, state, t)

x1 = L1*sin(y[:, 0])
y1 = -L1*cos(y[:, 0])

x2 = L2*sin(y[:, 2]) + x1
y2 = -L2*cos(y[:, 2]) + y1

fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(autoscale_on=False, xlim=(-L, L), ylim=(-L, 1.))
ax.set_aspect('equal')
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
trace, = ax.plot([], [], ',-', lw=1)
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
history_x, history_y = deque(maxlen=history_len), deque(maxlen=history_len)


def animate(i):
    thisx = [0, x1[i], x2[i]]
    thisy = [0, y1[i], y2[i]]

    if i == 0:
        history_x.clear()
        history_y.clear()

    history_x.appendleft(thisx[2])
    history_y.appendleft(thisy[2])

    line.set_data(thisx, thisy)
    trace.set_data(history_x, history_y)
    time_text.set_text(time_template % (i*dt))
    return line, trace, time_text


ani = animation.FuncAnimation(
    fig, animate, len(y), interval=dt*1000, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="360">

# %% [markdown]
# ## **seaborn**
# > - 많은 데이터분석가들이 주로 사용하는 시각화 라이브러리
# > - matplotlib에 비해 기본적인 시각적 심미성이 뛰어납니다.
# > - matplotlib에서 지원하지 않는 다양한 형태의 시각화도구를 제공.
# >- https://seaborn.pydata.org/examples/index.html
# >- 예쁘지만 커스텀은 힘들다는 단점
#
#
# **[colab 환경에서 아래 코드를 실행했을 때 그래프가 출력되지 않는다면?]**
# >- 런타임 다시 시작하기
#
#
# **시각화 패키지 plotly**
# >- https://plotly.com/python/
# >- mouse over, 지도에 floating과 mapping 등 다양한 interactive graph 제공해 매우 핫함!
# >- 웹에도 게시 가능(대시보드 등으로 활용)
#
# **지도에 데이터를 표시할 때 많이 사용하는 folium**
# >- https://github.com/python-visualization/folium

# %%
# 패키지 설치
# !pip install seaborn

# 패키지 import
import seaborn as sns

# %% [markdown]
# ### barplot

# %%
# sns는 plt 함수 뒤에 plot만 붙여주면 되는 경우 많다
# 주피터노트북에서 interactive 매직 명령어(%matplotlib notebook) 그래프 출력됨
plt.figure(figsize=(15,8))
sns.barplot(df['sub_grade'].value_counts().sort_index().index, df['sub_grade'].value_counts().sort_index().values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### countplot

# %%
# 쉬운 방법으로 barplot 구현이 가능하다. 
# 간단하게 볼떄는 countplot 많이 사용(단, 정렬 기능이 없다는 단점)
plt.figure(figsize=(15,8))
# sns.countplot(df['sub_grade'].value_counts().sort_index().index, df['sub_grade'].value_counts().sort_index().values)  # old
sns.countplot(df['grade'])  # new 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# new version : 권장되는 방법
plt.figure(figsize=(15,8))
sns.countplot(data=df, x='grade')
plt.show()

# %% [markdown]
# ### distplot(히스토그램)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['loan_amnt'])  
plt.show()

# 히스토그램의 분포 그래프(distribution : 적분)도 보여줌  = density(확률밀도함수) : 전체 그래프를 더하면 적분값 1
# histplot은 분포 그래프가 나오지 않는다.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### scatterplot

# %%
plt.figure(figsize=(15,6))
# sns.scatterplot(df['loan_amnt'], df['installment'])  # old

# hue option으로 범례표시 : 만기가 길수록 원리금이 적어짐
sns.scatterplot(data=df, x ='loan_amnt',  y= 'installment', hue='term')   # new   
plt.show()

# seaborn으로 그리면 plt보다 outline이 더 선명하게 보임

# %%
# Out:
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# #### 데이터 구분을 포함한 scatterplot (범례지정)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x ='loan_amnt',  y= 'installment', hue='grade')    
plt.show()

# seaborn으로 범례표시하면 plt보다 훨씬 더 많은 인사이트를 얻을 수 있음(barplot 등에도 hue값 지정할 수 있음)

# %% [markdown]
# ### boxplot
# - 데이터 분포 표시
# - 다른 데이터와의 관계
# - outliers, median, quantile, min, max

# %%
# 굉장히 많이 사용
# 각각의 box하나당 해당 데이터의 사분위수, 중앙값, 최대, 최소값을 표기한다.

plt.figure(figsize=(15,6))
sns.boxplot(data = df.sort_values(by='grade'), x ='grade',  y= 'int_rate')  # scatterplot에는 hue를 많이 사용하지만, boxplot에는 이미 많은 정보를 담고 있어 보통 hue option 주지 않는다.   
plt.show()

# x축은 신용등급, y축은 이자율
# 등급이 가장 낮으면(G) 이자율은 고정이다  = 예대금리 한도가 있음
# D, E의 이자 분포가 크다
# 중요한 정보!!  등급별 최대최소구간이 겹치지 않는다 = 신용등급에 따라 이자율이 정해져 있다
# B, C, D등급임에도 outlier는 A등급의 이자율보다 낮다.-> 우선 정상데이터인지 의심(df에서 샘플링해서 view값 보자)

# %%
# sampling
df[(df['int_rate'] <= 7) & (df['grade'] != 'A')]

# 모두 6% 고정금리
# 11617은 회사 직원이라 우대 금리를 받은 듯
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 639   NaN        NaN      30000        30000          30000.0   60 months
# 11617 NaN        NaN      20000        20000          20000.0   60 months
# 12022 NaN        NaN      18000        18000          18000.0   60 months
# 18045 NaN        NaN      10000        10000          10000.0   36 months
# 18632 NaN        NaN      11475        11475          11475.0   36 months
# 19244 NaN        NaN      25000        25000          25000.0   60 months
#
#        int_rate  installment grade sub_grade  ...  \
# 639         6.0       584.87     B        B1  ...
# 11617       6.0       369.56     D        D3  ...
# 12022       6.0       340.26     C        C2  ...
# 18045       6.0       305.83     C        C3  ...
# 18632       6.0       343.33     C        C3  ...
# 19244       6.0       473.23     D        D3  ...
#
#       hardship_payoff_balance_amount hardship_last_payment_amount  \
# ...

# %%
# 이상치 탐색
df[(df['int_rate'] <= 7) & (df['grade'] != 'A')]['emp_title']
# Out:
# 639                     Assistant Principal
# 11617                       GS 09 Team Leaf
# 12022        Industrial Engineering Manager
# 18045                     Assistant Manager
# 18632    Emergency Preparedness Instructor
# 19244                      Officer, Captain
# Name: emp_title, dtype: object

# %% [markdown]
# ### jointplot

# %%
# loan_amnt, int_rate의 scatter plot(상관관계) + hist plot(분포)의 결합형태인 joint plot
# 상관관계가 분명히 보일 때 더 자세히 알아보기 위해 사용

plt.figure(figsize=(15,6))
sns.jointplot(data = df, x ='loan_amnt',  y= 'int_rate') 
plt.show()

# loan_amnt와 int_rate는 당연히 상관관계 있을 줄 알았지만 상관관계가 없다.

# %%
plt.figure(figsize=(15,6))
sns.jointplot(data = df, x ='loan_amnt',  y= 'int_rate', kind='hex') 
# 'kde' | 'hist' | 'hex' | 'reg' | 'resid'
plt.show()

# %% [markdown]
# ### pairplot
# >- 각 변수간 상관관계를 확인하는 scatterplot의 확장버전
# 데이터프레임의 모든 변수에 대한 상관관계를 그리드 형태의 scatter로 표현합니다.
# >- 오래 걸리기 때문에 데이터프레임 가공하는 것이 좋음

# %%
df= df[df.columns[:25]]

# %%
# 각 컬럼간 모든 scatter plot을 그리는 pairplot
plt.figure(figsize=(15,15))
sns.pairplot(data=df)
plt.show()

# 일대일 매칭되므로 동일한 column : loan_amnt, funded_amnt, funded_amnt_inv -> 컬럼 하나만 남겨도 됨 
# 전처리할 때, pairplot을 먼저 그려보기 : loan_amnt --- funded_amnt

# %% [markdown]
# ### heatmap
# > 각 변수간 상관관계를 모두 확인하고자 하는 목적은 pairplot과 같음
# 다만 scatterplot 형태가 아닌 상관계수를 계산하여 열지도로 표현
# 각 변수간 관계를 한눈에 보기 좋은 형태

# %%
# scatterplot보다 시간도 적게 걸리고(데이터 가공하지 않아도 됨), 직관적으로 상관관계를 파악할 수 있음(정량적 분석 가능)
# pairplot과 마찬가지로 grid 형태로 넣어야 함
df.corr()
# Out:
#                  id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# id              NaN        NaN        NaN          NaN              NaN
# member_id       NaN        NaN        NaN          NaN              NaN
# loan_amnt       NaN        NaN   1.000000     1.000000         0.999989
# funded_amnt     NaN        NaN   1.000000     1.000000         0.999989
# funded_amnt_inv NaN        NaN   0.999989     0.999989         1.000000
# int_rate        NaN        NaN   0.056976     0.056976         0.057418
# installment     NaN        NaN   0.946254     0.946254         0.946070
# annual_inc      NaN        NaN   0.255403     0.255403         0.255382
# url             NaN        NaN        NaN          NaN              NaN
# desc            NaN        NaN        NaN          NaN              NaN
# dti             NaN        NaN   0.037267     0.037267         0.037246
#
#                  int_rate  installment  annual_inc  url  desc       dti
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr())
plt.show()

# 값이 없는 column(id...)은 비어서 나옴
# 색깔이 진할수록 음의 상관관계 강함, 색깔이 연할수록 양의 상관관계 강함

# heatmap에서 최댓값, 최솟값만 다른 색깔로 구별되게 출력하는 방법이 있을까?
# pairplot, heatmap으로 상관관계 있는 두 column만 골라서 -> boxplot, jointplot을 그려 자세히 분석
# 데이터는 범위가 좁을수록 deep해진다.
